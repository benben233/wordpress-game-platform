# %% [markdown]
# # Games Recommender System
#
# In this notebook, I will attempt at implementing a few recommendation algorithms (content based, popularity based and collaborative filtering) and try to build an ensemble of these models to come up with our final recommendation system. As a first step, I will build my simple recommender system.

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %% [markdown]
# ## Simple Recommender
#
# The Simple Recommender offers generalized recommendations to every user based on popularity and (sometimes) genre. The basic idea behind this recommender is that games that are more popular and more critically acclaimed will have a higher probability of being liked by the average audience. This model does not give personalized recommendations based on the user.
#
# The implementation of this model is extremely trivial. All we have to do is sort our games based on ratings and popularity and display the top games of our list. As an added step, we can pass in a genre argument to get the top games of a particular genre.

# %%
md = pd.read_csv('steamspy_data.csv', dtype=
    {'positive': int, 'negative': int})

md['vote_count'] = md['positive'] + md['negative']
md['vote_average'] = md['positive'] / md['vote_count']
md.head()
# Out:
#    appid                       name         developer publisher  score_rank
# 0     10             Counter-Strike             Valve     Valve         NaN  \
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever
# 0    124534      3339          0  10,000,000 .. 20,000,000            17612  \
# 1      3318       633          0   5,000,000 .. 10,000,000              277
# 2      3416       398          0   5,000,000 .. 10,000,000              187
# 3      1273       267          0   5,000,000 .. 10,000,000              258
# 4      5250       288          0   5,000,000 .. 10,000,000              624
#
#    ...  median_2weeks  price  initialprice  discount
# 0  ...             26  999.0         999.0       0.0  \
# 1  ...             15  499.0         499.0       0.0
# 2  ...              0  499.0         499.0       0.0
# 3  ...              0  499.0         499.0       0.0
# 4  ...              0  499.0         499.0       0.0
#
#                                            languages   genre    ccu
# 0  English, French, German, Italian, Spanish - Sp...  Action  14923  \
# 1  English, French, German, Italian, Spanish - Sp...  Action     87
# 2  English, French, German, Italian, Spanish - Spain  Action    130
# 3  English, French, German, Italian, Spanish - Sp...  Action      4
# 4                    English, French, German, Korean  Action     71
#
#                                                 tags  vote_count vote_average
# 0  {'Action': 2681, 'FPS': 2048, 'Multiplayer': 1...      127873     0.973888
# 1  {'Action': 208, 'FPS': 188, 'Multiplayer': 172...        3951     0.839787
# 2  {'FPS': 138, 'World War II': 122, 'Multiplayer...        3814     0.895648
# 3  {'Action': 85, 'FPS': 71, 'Multiplayer': 58, '...        1540     0.826623
# 4  {'FPS': 235, 'Action': 211, 'Sci-fi': 166, 'Si...        5538     0.947996
#
# [5 rows x 22 columns]

# %% [markdown]
# I use the Ratings to come up with our **Top games Chart.** I will use IMDB's *weighted rating* formula to construct my chart. Mathematically, it is represented as follows:
#
# Weighted Rating (WR) = $(\frac{v}{v + m} . R) + (\frac{m}{v + m} . C)$
#
# where,
# * *v* is the number of votes
# * *m* is the minimum votes required to be listed in the chart
# * *R* is the average rating
# * *C* is the mean vote across the whole report
#
# The next step is to determine an appropriate value for *m*, the minimum votes required to be listed in the chart. We will use **95th percentile** as our cutoff. In other words, for a game to feature in the charts, it must have more votes than at least 95% of the games in the list.
# I will build our overall Top Chart and will define a function to build charts for a particular genre. Let's begin!

# %%
md.shape
# Out:
# (29235, 22)

# %%
print(f"C = {md['vote_average'].mean()}")
print(f"m95 = {md['vote_count'].quantile(0.95)}")
md[md['vote_count'] >= 2613].copy().shape
# Out:
# C = 0.7117033053319257
# m95 = 2613.5999999999985
# (1463, 22)

# %% [markdown]
# Therefore, to qualify to be considered for the chart, a game has to have at least **2613 votes**. We also see that the average rating is **0.71**. And **1463** games qualify to be on our chart.

# %%
def weighted_rating(df, percentile=0.95):
    C = df['vote_average'].mean()
    m = df['vote_count'].quantile(percentile)
    qualified = df[df['vote_count'] >= m].copy()
    R = qualified['vote_average']
    v = qualified['vote_count']
    qualified['weighted_rating'] = (v / (v + m) * R) + (m / (m + v) * C)
    qualified = qualified.sort_values('weighted_rating', ascending=False)
    return qualified

# %% [markdown]
# ### Top games

# %%
weighted_rating(md).head()
# Out:
#        appid                      name           developer
# 23       620                  Portal 2               Valve  \
# 3361  292030  The Witcher 3: Wild Hunt      CD PROJEKT RED
# 8292  427520                  Factorio  Wube Software LTD.
# 0         10            Counter-Strike               Valve
# 1298  105600                  Terraria            Re-Logic
#
#                publisher  score_rank  positive  negative  userscore
# 23                 Valve         NaN    138220      1891          0  \
# 3361      CD PROJEKT RED         NaN    202930      4798          0
# 8292  Wube Software LTD.         NaN     47918       723          0
# 0                  Valve         NaN    124534      3339          0
# 1298            Re-Logic         NaN    255600      7797          0
#
#                         owners  average_forever  ...   price  initialprice
# 23    10,000,000 .. 20,000,000             1102  ...   999.0         999.0  \
# 3361   5,000,000 .. 10,000,000             3068  ...  3999.0        3999.0
# 8292    1,000,000 .. 2,000,000            10087  ...  3000.0        3000.0
# 0     10,000,000 .. 20,000,000            17612  ...   999.0         999.0
# 1298   5,000,000 .. 10,000,000             5585  ...   999.0         999.0
#
#       discount                                          languages
# 23         0.0  English, French, German, Spanish - Spain, Czec...  \
# 3361       0.0  English, French, Italian, German, Spanish - Sp...
# 8292       0.0  English, French, Italian, German, Spanish - Sp...
# 0          0.0  English, French, German, Italian, Spanish - Sp...
# 1298       0.0  English, French, Italian, German, Spanish - Sp...
#
#                                                   genre    ccu
# 23                                    Action, Adventure   1924  \
# 3361                                                RPG  16248
# 8292  Casual, Indie, Simulation, Strategy, Early Access   9464
# 0                                                Action  14923
# 1298                      Action, Adventure, Indie, RPG  21625
#
#                                                    tags vote_count
# 23    {'Puzzle': 4024, 'Co-op': 2871, 'First-Person'...     140111  \
# 3361  {'Open World': 6050, 'RPG': 5688, 'Story Rich'...     207728
# 8292  {'Early Access': 524, 'Base-Building': 1597, '...      48641
# 0     {'Action': 2681, 'FPS': 2048, 'Multiplayer': 1...     127873
# 1298  {'Sandbox': 7173, 'Adventure': 5956, 'Survival...     263397
#
#       vote_average weighted_rating
# 23        0.986504        0.981471
# 3361      0.976902        0.973607
# 8292      0.985136        0.971193
# 0         0.973888        0.968637
# 1298      0.970398        0.967857
#
# [5 rows x 23 columns]

# %% [markdown]
# We see that, **Portal 2**, **The Witcher 3: Wild Hunt** and **Factorio** occur at the very top of our chart.
#
# Let us now construct our function that builds charts for particular genres. For this, we will relax our default conditions to the **85** percentile instead of 95.

# %%
def build_chart(genre, percentile=0.85):
    md.dropna(subset= ['genre'],inplace=True)
    df = md[md.genre.apply(lambda x: genre in x)]
    return weighted_rating(df, percentile)

# %% [markdown]
# Let us see our method in action by displaying the Top 10 Casual games (Casual almost didn't feature at all in our Generic Top Chart despite being one of the most popular genres).
# ### Top Casual games

# %%
build_chart('Casual').head()
# Out:
#        appid                    name            developer
# 8292  427520                Factorio   Wube Software LTD.  \
# 2645  264200  One Finger Death Punch  Silver Dollar Games
# 2323  252150                   Grimm     Spicyhorse Games
# 8102  420530                 OneShot      Little Cat Feet
# 2037  238460     BattleBlock Theater         The Behemoth
#
#                 publisher  score_rank  positive  negative  userscore
# 8292   Wube Software LTD.         NaN     47918       723          0  \
# 2645  Silver Dollar Games         NaN     14181       256          0
# 2323     Spicyhorse Games         NaN     27870       602          0
# 8102               Degica         NaN     10985       220          0
# 2037         The Behemoth         NaN     47342      1290          0
#
#                       owners  average_forever  ...   price  initialprice
# 8292  1,000,000 .. 2,000,000            10087  ...  3000.0        3000.0  \
# 2645    500,000 .. 1,000,000              149  ...   499.0         499.0
# 2323    500,000 .. 1,000,000              256  ...     0.0           0.0
# 8102      200,000 .. 500,000              327  ...   999.0         999.0
# 2037  2,000,000 .. 5,000,000              774  ...  1499.0        1499.0
#
#       discount                                          languages
# 8292       0.0  English, French, Italian, German, Spanish - Sp...  \
# 2645       0.0                                            English
# 2323       0.0                                            English
# 8102       0.0  English, Japanese, French, Spanish - Spain, Po...
# 2037       0.0  English, French, Italian, German, Spanish - Sp...
#
#                                                   genre   ccu
# 8292  Casual, Indie, Simulation, Strategy, Early Access  9464  \
# 2645                              Action, Casual, Indie    63
# 2323                                      Casual, Indie   872
# 8102                           Adventure, Casual, Indie    33
# 2037                   Action, Adventure, Casual, Indie   261
#
#                                                    tags vote_count
# 8292  {'Early Access': 524, 'Base-Building': 1597, '...      48641  \
# 2645  {'Action': 280, 'Fast-Paced': 257, 'Indie': 22...      14437
# 2323  {'Indie': 61, 'Casual': 60, 'Episodic': 40, 'V...      28472
# 8102  {'Story Rich': 453, 'Pixel Graphics': 428, 'Gr...      11205
# 2037  {'Comedy': 924, 'Co-op': 854, 'Platformer': 79...      48632
#
#       vote_average weighted_rating
# 8292      0.985136        0.984120
# 2645      0.982268        0.978909
# 2323      0.978856        0.977165
# 8102      0.980366        0.976084
# 2037      0.973474        0.972501
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Content Based Recommender
#
# The recommender we built in the previous section suffers some severe limitations. For one, it gives the same recommendation to everyone, regardless of the user's personal taste. If a person who loves casual games (and hates action) were to look at our Top 15 Chart, s/he wouldn't probably like most of the games. If s/he were to go one step further and look at our charts by genre, s/he wouldn't still be getting the best recommendations.
#
# To personalise our recommendations more, I am going to build an engine that computes similarity between games based on certain metrics and suggests games that are most similar to a particular game that a user liked. Since we will be using game metadata (or content) to build this engine, this also known as **Content Based Filtering.**
#
# I will build Content Based Recommenders based on:
# * Game description, developer, tags
#
# Also I will be using a subset of all the games available to us due to limiting computing power available to me.

# %%
smd = pd.read_csv('game.csv')
smd.shape
smd.head()
# Out:
#    appid                       name  positive_ratings  negative_ratings
# 0     10             Counter-Strike            124534              3339  \
# 1     20      Team Fortress Classic              3318               633
# 2     30              Day of Defeat              3416               398
# 3     40         Deathmatch Classic              1273               267
# 4     50  Half-Life: Opposing Force              5250               288
#
#      owners   reviews release_date         developer
# 0  20000000  0.973888   2000-11-01             Valve  \
# 1  10000000  0.839787   1999-04-01             Valve
# 2  10000000  0.895648   2003-05-01             Valve
# 3  10000000  0.826623   2001-06-01             Valve
# 4  10000000  0.947996   1999-11-01  Gearbox Software
#
#                             steamspy_tags
# 0        ['Action', 'FPS', 'Multiplayer']  \
# 1        ['Action', 'FPS', 'Multiplayer']
# 2  ['FPS', 'World War II', 'Multiplayer']
# 3        ['Action', 'FPS', 'Multiplayer']
# 4             ['FPS', 'Action', 'Sci-fi']
#
#                                       about_the_game
# 0  Play the world's number 1 online action game. ...  \
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...  \
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                         header_image
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...  \
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                           background
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...  \
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website publisher
# 0                          NaN     Valve
# 1                          NaN     Valve
# 2  http://www.dayofdefeat.com/     Valve
# 3                          NaN     Valve
# 4                          NaN     Valve

# %% [markdown]
# We have **1348** games available in our small games' metadata dataset.

# %% [markdown]
# ### Game Description Based Recommender
#
# Let us first try to build a recommender using game descriptions. We do not have a quantitative metric to judge our machine's performance so this will have to be done qualitatively.

# %%
tf = TfidfVectorizer(ngram_range=(1, 2), min_df=0, stop_words='english')

# %% [markdown]
# #### TF-IDF
#
# $tf$ is nature
#
# $idf = \ln {\frac{1+n}{1+df(t)}}+1 $
# Then normalize to unit vector

# %%
tfidf_matrix = tf.fit_transform(smd['about_the_game'])
tfidf_matrix.shape
# Out:
# (1348, 186545)

# %% [markdown]
# #### Cosine Similarity
#
# I will be using the Cosine Similarity to calculate a numeric quantity that denotes the similarity between two games. Mathematically, it is defined as follows:
#
# $cosine(x,y) = \frac{x. y^\intercal}{||x||.||y||} $
#
# Since we have used the TF-IDF Vectorizer, calculating the Dot Product will directly give us the Cosine Similarity Score. Therefore, we will use sklearn's **linear_kernel** instead of cosine_similarities since it is much faster.

# %%
cosine_sim = linear_kernel(tfidf_matrix)
cosine_sim
# Out:
# array([[1.        , 0.06290757, 0.0191225 , ..., 0.00241813, 0.00392128,
#         0.00796182],
#        [0.06290757, 1.        , 0.00742661, ..., 0.00430838, 0.01039487,
#         0.00859381],
#        [0.0191225 , 0.00742661, 1.        , ..., 0.00376203, 0.00255696,
#         0.00300565],
#        ...,
#        [0.00241813, 0.00430838, 0.00376203, ..., 1.        , 0.08161317,
#         0.13682499],
#        [0.00392128, 0.01039487, 0.00255696, ..., 0.08161317, 1.        ,
#         0.14864747],
#        [0.00796182, 0.00859381, 0.00300565, ..., 0.13682499, 0.14864747,
#         1.        ]])

# %% [markdown]
# We now have a pairwise cosine similarity matrix for all the games in our dataset. The next step is to write a function that returns the 30 most similar games based on the cosine similarity score.

# %%
def recommend(title):
    game = smd[smd['name'] == title]
    if len(game) > 1:
        print("There are duplications of same name. Choose index and use get_recommendations(idx)")
        print(game)
    elif len(game) == 0:
        print("Game Not Found")    
    else:
        indexes = get_recommendations(game.index[0])
        recommend_games = smd.iloc[indexes]
        return recommend_games[1:].set_index('appid')


def get_recommendations(idx):
    # return games index which similarity score bigger than 0.01
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    return [i[0] for i in sim_scores if i[1] > 0.01]

# %% [markdown]
# We're all set. Let us now try and get the top recommendations for a few games and see how good the recommendations are.

# %%
recommend('Counter-Strike').head(10)
# Out:
#                                     name  positive_ratings  negative_ratings
# appid
# 20                 Team Fortress Classic              3318               633  \
# 19830   Tom Clancy's Rainbow Six® 3 Gold               811                71
# 222880                        Insurgency             92355              9570
# 240320                            Panzar              2987              1609
# 7940    Call of Duty® 4: Modern Warfare®              8725               821
# 207230                       ArcheBlade™              5642              2086
# 21090                           F.E.A.R.              6371               438
# 39000                     Moonbase Alpha              9867              1166
# 41300                           Altitude              1540               128
# 681280                        Descenders               666                62
#
#           owners   reviews release_date
# appid
# 20      10000000  0.839787   1999-04-01  \
# 19830     200000  0.919501   2008-09-25
# 222880   5000000  0.906107   2014-01-22
# 240320   2000000  0.649913   2013-11-25
# 7940     2000000  0.913995   2007-11-12
# 207230   5000000  0.730072   2014-04-25
# 21090    2000000  0.935673   2010-05-21
# 39000    2000000  0.894317   2010-07-06
# 41300     500000  0.923261   2009-12-04
# 681280     20000  0.914835   2018-02-09
#
#                                        developer
# appid
# 20                                         Valve  \
# 19830   Red Storm Entertainment;Ubisoft Montreal
# 222880                     New World Interactive
# 240320                             Panzar Studio
# 7940                   Infinity Ward;Aspyr (Mac)
# 207230                           CodeBrush Games
# 21090        Monolith Productions, Inc.;Timegate
# 39000            Virtual Heroes;Army Game Studio
# 41300                               Nimbly Games
# 681280                                 RageSquid
#
#                                     steamspy_tags
# appid
# 20               ['Action', 'FPS', 'Multiplayer']  \
# 19830               ['Tactical', 'FPS', 'Action']
# 222880           ['FPS', 'Realistic', 'Tactical']
# 240320  ['Free to Play', 'Action', 'Multiplayer']
# 7940             ['FPS', 'Action', 'Multiplayer']
# 207230        ['Free to Play', 'Anime', 'Action']
# 21090                 ['Horror', 'FPS', 'Action']
# 39000     ['Space', 'Simulation', 'Free to Play']
# 41300         ['Free to Play', 'Action', 'Indie']
# 681280       ['Early Access', 'Sports', 'Racing']
#
#                                            about_the_game
# appid
# 20      One of the most popular online action games of...  \
# 19830   Raven Shield:<br>Command an elite multinationa...
# 222880  Take to the streets for intense close quarters...
# 240320  PANZAR is a fantasy multiplayer third-person s...
# 7940    The new action-thriller from the award-winning...
# 207230  <ul class="bb_ul"><li><strong>3D Fighting Game...
# 21090   Be the hero in your own cinematic epic of acti...
# 39000   NASA has once again landed on the lunar surfac...
# 41300   Blast your way across the cartoon skies in thi...
# 681280  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                         short_description
# appid
# 20      One of the most popular online action games of...  \
# 19830   Raven Shield:Command an elite multinational sq...
# 222880  Take to the streets for intense close quarters...
# 240320  PANZAR is a fantasy multiplayer third-person s...
# 7940    The new action-thriller from the award-winning...
# 207230  ArcheBlade is a free to play 3D multiplayer fi...
# 21090   Experience the original F.E.A.R. along with F....
# 39000   NASA has once again landed on the lunar surfac...
# 41300                 Now Available on PC, Mac and Linux!
# 681280  Descenders is extreme downhill freeriding for ...
#
#                                              header_image
# appid
# 20      https://steamcdn-a.akamaihd.net/steam/apps/20/...  \
# 19830   https://steamcdn-a.akamaihd.net/steam/apps/198...
# 222880  https://steamcdn-a.akamaihd.net/steam/apps/222...
# 240320  https://steamcdn-a.akamaihd.net/steam/apps/240...
# 7940    https://steamcdn-a.akamaihd.net/steam/apps/794...
# 207230  https://steamcdn-a.akamaihd.net/steam/apps/207...
# 21090   https://steamcdn-a.akamaihd.net/steam/apps/210...
# 39000   https://steamcdn-a.akamaihd.net/steam/apps/390...
# 41300   https://steamcdn-a.akamaihd.net/steam/apps/413...
# 681280  https://steamcdn-a.akamaihd.net/steam/apps/681...
#
#                                                background
# appid
# 20      https://steamcdn-a.akamaihd.net/steam/apps/20/...  \
# 19830   https://steamcdn-a.akamaihd.net/steam/apps/198...
# 222880  https://steamcdn-a.akamaihd.net/steam/apps/222...
# 240320  https://steamcdn-a.akamaihd.net/steam/apps/240...
# 7940    https://steamcdn-a.akamaihd.net/steam/apps/794...
# 207230  https://steamcdn-a.akamaihd.net/steam/apps/207...
# 21090   https://steamcdn-a.akamaihd.net/steam/apps/210...
# 39000   https://steamcdn-a.akamaihd.net/steam/apps/390...
# 41300   https://steamcdn-a.akamaihd.net/steam/apps/413...
# 681280  https://steamcdn-a.akamaihd.net/steam/apps/681...
#
#                                             website
# appid
# 20                                              NaN  \
# 19830                                           NaN
# 222880          https://www.newworldinteractive.com
# 240320                       https://www.panzar.com
# 7940              http://www.charlieoscardelta.com/
# 207230                    http://www.codebrush.net/
# 21090   https://wbgamessupport.wbgames.com/hc/en-us
# 39000             http://www.nasa.gov/moonbasealpha
# 41300                      http://altitudegame.com/
# 681280                http://www.descendersgame.com
#
#                                      publisher
# appid
# 20                                       Valve
# 19830                                  Ubisoft
# 222880                   New World Interactive
# 240320              OVALIS INVESTMENTS LIMITED
# 7940                                Activision
# 207230                         Codebrush Games
# 21090   Warner Bros. Interactive Entertainment
# 39000                                     NASA
# 41300                             Nimbly Games
# 681280                          No More Robots

# %% [markdown]
# But unfortunately, that is all this system can do at the moment. This is not of much use to most people as it doesn't take into considerations very important features such as developer and genre, which determine the rating and the popularity of a game.
#
# Therefore, we are going to use much more suggestive metadata than **description**. In the next subsection, we will build a more sophisticated recommender that takes **genre** and **developer** into consideration.

# %% [markdown]
# ### Metadata Based Recommender
#
# To build our standard metadata based content recommender, we will need to merge our current dataset with the tags and the developer datasets. Let us prepare this data as our first step.

# %%
smd['steamspy_tags'] = smd['steamspy_tags'].apply(literal_eval)

# %% [markdown]
# My approach to building the recommender is going to be extremely *hacky*. What I plan on doing is creating a metadata dump for every game which consists of **tags** and **developer**. Then I use a **Count Vectorizer** to create our count matrix as we did in the Description Recommender. The remaining steps are similar to what we did earlier: we calculate the cosine similarities and return games that are most similar.
#
# These are steps I follow in the preparation of my data:
# 1. **Strip Spaces and Convert to Lowercase** from all our features.
# 2. Mention **tags** and **developer** 3 times to give it more weight.

# %%
strip = lambda x: str(x).replace(" ", "").lower()
tags = smd['steamspy_tags'].apply(lambda x: [strip(i) for i in x])
developer = smd['developer'].apply(lambda x: [strip(x)] * 3)
tags *= 3
tags
# Out:
# 0       [action, fps, multiplayer, action, fps, multip...
# 1       [action, fps, multiplayer, action, fps, multip...
# 2       [fps, worldwarii, multiplayer, fps, worldwarii...
# 3       [action, fps, multiplayer, action, fps, multip...
# 4       [fps, action, sci-fi, fps, action, sci-fi, fps...
#                               ...
# 1343    [adventure, visualnovel, anime, adventure, vis...
# 1344    [freetoplay, psychologicalhorror, indie, freet...
# 1345    [indie, bullethell, faith, indie, bullethell, ...
# 1346    [psychologicalhorror, datingsim, casual, psych...
# 1347    [strategy, indie, citybuilder, strategy, indie...
# Name: steamspy_tags, Length: 1348, dtype: object

# %% [markdown]
# #### Keywords
#
# We will do a small amount of pre-processing of our keywords before putting them to any use. As a first step, we calculate the frequenct counts of every keyword that appears in the dataset.

# %%
s = pd.DataFrame(np.concatenate(tags)).value_counts()
s[:5]
# Out:
# action        365
# indie         336
# freetoplay    203
# adventure     187
# rpg           156
# Name: count, dtype: int64

# %% [markdown]
# Keywords occur in frequencies ranging from 1 to 603. We do not have any use for keywords that occur only once. Therefore, these can be safely removed. Finally, we will convert every word to its stem so that words such as *Dogs* and *Dog* are considered the same.

# %%
from nltk.stem.snowball import SnowballStemmer

stem = SnowballStemmer('english').stem


def filter_keywords(x):
    words = []
    for i in x:
        if i in s:
            for a in i.split():
                words.append(stem(a))
    return words

# %%
s= s[s>1]
keywords = tags.apply(filter_keywords)
soup = keywords + developer
soup = soup.apply(lambda x: ' '.join(x))
soup += ' ' + smd['about_the_game']
soup.head()
# Out:
# 0    action fps multiplay action fps multiplay acti...
# 1    action fps multiplay action fps multiplay acti...
# 2    fps worldwarii multiplay fps worldwarii multip...
# 3    action fps multiplay action fps multiplay acti...
# 4    fps action sci-fi fps action sci-fi fps action...
# dtype: object

# %%
count = CountVectorizer(ngram_range=(1, 2), min_df=0, stop_words='english')
count_matrix = count.fit_transform(soup)

cosine_sim = cosine_similarity(count_matrix)

# %% [markdown]
# We will reuse the get_recommendations function that we had written earlier. Since our cosine similarity scores have changed, we expect it to give us different (and probably better) results. Let us check for **Counter-Strike** again and see what recommendations I get this time around.

# %%
recommend('Counter-Strike').head(10)
# Out:
#                                  name  positive_ratings  negative_ratings
# appid
# 60                           Ricochet              2758               684  \
# 20              Team Fortress Classic              3318               633
# 360      Half-Life Deathmatch: Source              1362               473
# 320           Half-Life 2: Deathmatch              6020               787
# 40                 Deathmatch Classic              1273               267
# 240            Counter-Strike: Source             76640              3497
# 80     Counter-Strike: Condition Zero             12120              1439
# 70                          Half-Life             27755              1100
# 300             Day of Defeat: Source             10489              1210
# 340           Half-Life 2: Lost Coast              5783              1020
#
#          owners   reviews release_date developer
# appid
# 60     10000000  0.801278   2000-11-01     Valve  \
# 20     10000000  0.839787   1999-04-01     Valve
# 360    10000000  0.742234   2006-05-01     Valve
# 320    20000000  0.884384   2004-11-01     Valve
# 40     10000000  0.826623   2001-06-01     Valve
# 240    20000000  0.956362   2004-11-01     Valve
# 80     20000000  0.893871   2004-03-01     Valve
# 70     10000000  0.961878   1998-11-08     Valve
# 300    10000000  0.896572   2010-07-12     Valve
# 340    20000000  0.850066   2005-10-27     Valve
#
#                           steamspy_tags
# appid
# 60           [Action, FPS, Multiplayer]  \
# 20           [Action, FPS, Multiplayer]
# 360          [Action, FPS, Multiplayer]
# 320          [Action, FPS, Multiplayer]
# 40           [Action, FPS, Multiplayer]
# 240          [Action, FPS, Multiplayer]
# 80           [Action, FPS, Multiplayer]
# 70               [FPS, Classic, Action]
# 300    [FPS, World War II, Multiplayer]
# 340         [FPS, Action, Singleplayer]
#
#                                           about_the_game
# appid
# 60     A futuristic action game that challenges your ...  \
# 20     One of the most popular online action games of...
# 360    Half-Life Deathmatch: Source is a recreation o...
# 320    Fast multiplayer action set in the Half-Life 2...
# 40     Enjoy fast-paced multiplayer gaming with Death...
# 240    THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 80     With its extensive Tour of Duty campaign, a ne...
# 70     Named Game of the Year by over 50 publications...
# 300    Day of Defeat offers intense online action gam...
# 340    Originally planned as a section of the Highway...
#
#                                        short_description
# appid
# 60     A futuristic action game that challenges your ...  \
# 20     One of the most popular online action games of...
# 360    Half-Life Deathmatch: Source is a recreation o...
# 320    Fast multiplayer action set in the Half-Life 2...
# 40     Enjoy fast-paced multiplayer gaming with Death...
# 240    Just updated to include player stats, achievem...
# 80     With its extensive Tour of Duty campaign, a ne...
# 70     Named Game of the Year by over 50 publications...
# 300    Valve's WWII Multiplayer Classic - Now availab...
# 340    Originally planned as a section of the Highway...
#
#                                             header_image
# appid
# 60     https://steamcdn-a.akamaihd.net/steam/apps/60/...  \
# 20     https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 360    https://steamcdn-a.akamaihd.net/steam/apps/360...
# 320    https://steamcdn-a.akamaihd.net/steam/apps/320...
# 40     https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 240    https://steamcdn-a.akamaihd.net/steam/apps/240...
# 80     https://steamcdn-a.akamaihd.net/steam/apps/80/...
# 70     https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 300    https://steamcdn-a.akamaihd.net/steam/apps/300...
# 340    https://steamcdn-a.akamaihd.net/steam/apps/340...
#
#                                               background
# appid
# 60     https://steamcdn-a.akamaihd.net/steam/apps/60/...  \
# 20     https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 360    https://steamcdn-a.akamaihd.net/steam/apps/360...
# 320    https://steamcdn-a.akamaihd.net/steam/apps/320...
# 40     https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 240    https://steamcdn-a.akamaihd.net/steam/apps/240...
# 80     https://steamcdn-a.akamaihd.net/steam/apps/80/...
# 70     https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 300    https://steamcdn-a.akamaihd.net/steam/apps/300...
# 340    https://steamcdn-a.akamaihd.net/steam/apps/340...
#
#                            website publisher
# appid
# 60                             NaN     Valve
# 20                             NaN     Valve
# 360                            NaN     Valve
# 320                            NaN     Valve
# 40                             NaN     Valve
# 240                            NaN     Valve
# 80                             NaN     Valve
# 70       http://www.half-life.com/     Valve
# 300    http://www.dayofdefeat.com/     Valve
# 340      http://www.half-life2.com     Valve

# %% [markdown]
# I am much more satisfied with the results I get this time around. The recommendations seem to have recognized other Valve games (due to the high weightage given to developer) and put them as top recommendations.
# We can of course experiment on this engine by trying out different weights for our features (directors, actors, genres), limiting the number of keywords that can be used in the soup, weighing genres based on their frequency, only showing games with the same languages, etc.

# %% [markdown]
# #### Ratings and Popularity
#
# One thing that we notice about our recommendation system is that it recommends games regardless of *ratings* and *popularity*.
#
# Therefore, we will add a mechanism to reorder and return games which are popular and have had a good critical response.
#
# First I will take the top 25 games based on similarity scores. Then we will calculate the weighted rating of each game using IMDB's formula like we did in the Simple Recommender section. And using vote of the 60% as the value $m$ of these similar games, then reorder.

# %%
def improved_recommendations(title):
    games = recommend(title)[:25]
    md_s = pd.read_csv('steamspy_data.csv', dtype=
    {'positive': int, 'negative': int})

    md_s['vote_count'] = md_s['positive'] + md_s['negative']
    md_s['vote_average'] = md_s['positive'] / md_s['vote_count']
    md_s = md_s[md_s['appid'].isin(games.index)]
    return weighted_rating(md_s, 0.6)

# %%
improved_recommendations('Counter-Strike')
# Out:
#        appid                              name
# 9        220                       Half-Life 2  \
# 10       240            Counter-Strike: Source
# 6         70                         Half-Life
# 19       440                   Team Fortress 2
# 18       420          Half-Life 2: Episode Two
# 2480  259080     Just Cause 2: Multiplayer Mod
# 12       300             Day of Defeat: Source
# 7         80    Counter-Strike: Condition Zero
# 25       730  Counter-Strike: Global Offensive
# 1404  202970        Call of Duty: Black Ops II
#
#                              developer    publisher  score_rank  positive
# 9                                Valve        Valve         NaN     67902  \
# 10                               Valve        Valve         NaN     76640
# 6                                Valve        Valve         NaN     27755
# 19                               Valve        Valve         NaN    515879
# 18                               Valve        Valve         NaN     13902
# 2480                 Avalanche Studios  Square Enix         NaN     12261
# 12                               Valve        Valve         NaN     10489
# 7                                Valve        Valve         NaN     12120
# 25    Valve, Hidden Path Entertainment        Valve         NaN   2644404
# 1404                          Treyarch   Activision         NaN     25827
#
#       negative  userscore                     owners  average_forever  ...
# 9         2419          0   10,000,000 .. 20,000,000              691  ...  \
# 10        3497          0   10,000,000 .. 20,000,000             6842  ...
# 6         1100          0    5,000,000 .. 10,000,000             1300  ...
# 19       34036          0   20,000,000 .. 50,000,000             8495  ...
# 18         696          0    5,000,000 .. 10,000,000              354  ...
# 2480      1099          0     1,000,000 .. 2,000,000              431  ...
# 12        1210          0    5,000,000 .. 10,000,000             1356  ...
# 7         1439          0   10,000,000 .. 20,000,000              427  ...
# 25      402313          0  50,000,000 .. 100,000,000            22494  ...
# 1404      4658          0     2,000,000 .. 5,000,000              524  ...
#
#        price  initialprice  discount
# 9      999.0         999.0       0.0  \
# 10     999.0         999.0       0.0
# 6      999.0         999.0       0.0
# 19       0.0           0.0       0.0
# 18     799.0         799.0       0.0
# 2480     0.0           0.0       0.0
# 12     999.0         999.0       0.0
# 7      999.0         999.0       0.0
# 25       0.0           0.0       0.0
# 1404  5999.0        5999.0       0.0
#
#                                               languages                 genre
# 9     English, French, German, Italian, Korean, Span...                Action  \
# 10    English, French, German, Italian, Japanese, Ko...                Action
# 6     English, French, German, Italian, Spanish - Sp...                Action
# 19    English, Danish, Dutch, Finnish, French, Germa...  Action, Free to Play
# 18    English, French, German, Russian, Danish, Dutc...                Action
# 2480  English, French, German, Italian, Spanish - Sp...     Action, Adventure
# 12                                              English                Action
# 7     English, French, German, Italian, Spanish - Sp...                Action
# 25    Czech, Danish, Dutch, English, Finnish, French...  Action, Free to Play
# 1404  English, French, German, Italian, Spanish - Spain                Action
#
#          ccu                                               tags vote_count
# 9        628  {'FPS': 2056, 'Action': 1761, 'Sci-fi': 1589, ...      70321  \
# 10      5541  {'Action': 1785, 'FPS': 1617, 'Multiplayer': 1...      80137
# 6        374  {'FPS': 929, 'Classic': 874, 'Action': 766, 'S...      28855
# 19     41282  {'Free to Play': 17555, 'Multiplayer': 10499, ...     549915
# 18       143  {'FPS': 536, 'Action': 444, 'Sci-fi': 390, 'Si...      14598
# 2480      55  {'Open World': 315, 'Multiplayer': 288, 'Actio...      13360
# 12       576  {'FPS': 287, 'World War II': 272, 'Multiplayer...      11699
# 7        627  {'Action': 377, 'FPS': 311, 'Multiplayer': 224...      13559
# 25    507652  {'FPS': 20508, 'Multiplayer': 16566, 'Shooter'...    3046717
# 1404     223  {'Action': 1090, 'Multiplayer': 1068, 'FPS': 9...      30485
#
#       vote_average weighted_rating
# 9         0.965601        0.955127
# 10        0.956362        0.948069
# 6         0.961878        0.941254
# 19        0.938107        0.937102
# 18        0.952322        0.923767
# 2480      0.917740        0.902650
# 12        0.896572        0.890195
# 7         0.893871        0.889152
# 25        0.867952        0.868002
# 1404      0.847204        0.856143
#
# [10 rows x 23 columns]

# %% [markdown]
# Let me also get the recommendations for **Dota 2**

# %%
improved_recommendations('Dota 2')
# Out:
#         appid                                               name
# 1889   230410                                           Warframe  \
# 2523   260230  Valiant Hearts: The Great War / Soldats Inconn...
# 1721   220240                                          Far Cry 3
# 3705   302510                                  Ryse: Son of Rome
# 2263   250400                                     How to Survive
# 22869  823130                     Totally Accurate Battlegrounds
# 4405   325610                                  Total War: ATTILA
# 2154   244930                                               SNOW
# 11388  513710                                               SCUM
# 23206  834910                                              ATLAS
#
#                                                developer         publisher
# 1889                                    Digital Extremes  Digital Extremes  \
# 2523                                 Ubisoft Montpellier           Ubisoft
# 1721   Ubisoft Montreal, Massive Entertainment, and U...           Ubisoft
# 3705                                              Crytek           Crytek
# 2263                                        Eko Software         505 Games
# 22869                                           Landfall          Landfall
# 4405                                   CREATIVE ASSEMBLY              SEGA
# 2154               Poppermost Productions, WastedStudios            Crytek
# 11388                                 Gamepires, Croteam  Devolver Digital
# 23206                    Grapeshot Games, Instinct Games   Grapeshot Games
#
#        score_rank  positive  negative  userscore                    owners
# 1889          NaN    226541     20268          0  20,000,000 .. 50,000,000  \
# 2523          NaN     15650       709          0        200,000 .. 500,000
# 1721          NaN     46331      5622          0    2,000,000 .. 5,000,000
# 3705          NaN     14966      2939          0    1,000,000 .. 2,000,000
# 2263          NaN     12965      2751          0    1,000,000 .. 2,000,000
# 22869         NaN     20961      4890          0    1,000,000 .. 2,000,000
# 4405          NaN     12297      4469          0    1,000,000 .. 2,000,000
# 2154          NaN      7235      3754          0    1,000,000 .. 2,000,000
# 11388         NaN     15934      8556          0    1,000,000 .. 2,000,000
# 23206         NaN      8621     16359          0    1,000,000 .. 2,000,000
#
#        average_forever  ...   price  initialprice  discount
# 1889              5845  ...     0.0           0.0       0.0  \
# 2523               509  ...  1499.0        1499.0       0.0
# 1721               836  ...  1999.0        1999.0       0.0
# 3705               225  ...  1499.0        1499.0       0.0
# 2263               333  ...   149.0        1499.0      90.0
# 22869              478  ...   499.0         499.0       0.0
# 4405              2147  ...  4499.0        4499.0       0.0
# 2154              8180  ...     0.0           0.0       0.0
# 11388             1264  ...  1339.0        1999.0      33.0
# 23206             2755  ...  2999.0        2999.0       0.0
#
#                                                languages
# 1889   English, German, French, Italian, Korean, Span...  \
# 2523   English, French, Italian, German, Spanish - Sp...
# 1721   English, German, French, Italian, Spanish - Sp...
# 3705   English, French, Italian, German, Spanish - Sp...
# 2263   English, French, Italian, German, Spanish - Sp...
# 22869                                            English
# 4405   English, French, Italian, German, Spanish - Sp...
# 2154                                             English
# 11388       English, German, Russian, Simplified Chinese
# 23206  English, Simplified Chinese, Italian, German, ...
#
#                                                    genre    ccu
# 1889                                Action, Free to Play  64447  \
# 2523                                           Adventure     27
# 1721                                   Action, Adventure    524
# 3705                                              Action     76
# 2263                              Action, Adventure, RPG    383
# 22869                                      Action, Indie    162
# 4405                                            Strategy   2945
# 2154             Free to Play, Indie, Simulation, Sports     51
# 11388  Action, Adventure, Indie, Massively Multiplaye...   3036
# 23206  Action, Adventure, Massively Multiplayer, RPG,...   9036
#
#                                                     tags vote_count
# 1889   {'Free to Play': 8468, 'Action': 4969, 'Co-op'...     246809  \
# 2523   {'Atmospheric': 674, 'Historical': 618, 'World...      16359
# 1721   {'Open World': 2028, 'FPS': 1675, 'Action': 14...      51953
# 3705   {'Quick-Time Events': 667, 'Rome': 462, 'Actio...      17905
# 2263   {'Survival': 542, 'Zombies': 534, 'Crafting': ...      15716
# 22869  {'Multiplayer': 206, 'Funny': 189, 'Battle Roy...      25851
# 4405   {'Strategy': 650, 'Historical': 425, 'War': 38...      16766
# 2154   {'Sports': 332, 'Free to Play': 321, 'Multipla...      10989
# 11388  {'Early Access': 210, 'Survival': 391, 'Open W...      24490
# 23206  {'Early Access': 154, 'Survival': 195, 'Open W...      24980
#
#        vote_average weighted_rating
# 1889       0.917880        0.914912
# 2523       0.956660        0.912964
# 1721       0.891787        0.883202
# 3705       0.835856        0.835175
# 2263       0.824955        0.828193
# 22869      0.810839        0.816791
# 4405       0.733449        0.768592
# 2154       0.658386        0.737533
# 11388      0.650633        0.699993
# 23206      0.345116        0.474899
#
# [10 rows x 23 columns]

# %% [markdown]
# However, there is nothing much we can do about this. Therefore, we will conclude our Content Based Recommender section here and come back to it when we build a hybrid engine.

# %% [markdown]
# ## Collaborative Filtering
#
# Our content based engine suffers from some severe limitations. It is only capable of suggesting games which are *close* to a certain game. That is, it is not capable of capturing tastes and providing recommendations across genres.
#
# Also, the engine that we built is not really personal in that it doesn't capture the personal tastes and biases of a user. Anyone querying our engine for recommendations based on a game will receive the same recommendations for that game, regardless of who s/he is.
#
# Therefore, in this section, we will use a technique called **Collaborative Filtering** to make recommendations which is based on the idea that users similar to me can be used to predict how much I will like a particular product or service those users have used/experienced but I have not.

# %%
from surprise import Reader, Dataset, SVD
from surprise import accuracy
from surprise.model_selection import train_test_split

ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    app_id  helpful  funny        date  is_recommended  hours  user_id
# 0     730        0      0  2021-11-30               0  157.5    28396  \
# 1     570        0      0  2021-03-08               1  850.9   221458
# 2     730        0      0  2021-11-19               1   21.4   189524
# 3     730        2      0  2015-09-24               1  337.8   258631
# 4     730        3      0  2016-08-29               0  895.5  1882403
#
#    review_id
# 0          7
# 1         20
# 2         51
# 3         71
# 4        123

# %% [markdown]
# I will use the extremely powerful algorithms like **Singular Value Decomposition (SVD)** to minimise RMSE (Root Mean Square Error) and give great recommendations.

# %%
data = Dataset.load_from_df(ratings[['user_id', 'app_id', 'is_recommended']], Reader(rating_scale=(0, 1)))

# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=.25)

# We'll use the famous SVD algorithm.
algo = SVD()

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2862
# 0.28617204026237614

# %% [markdown]
# We get a mean **Root Mean Sqaure Error** about 0.3 which is more than good enough for our case. Let us now train on our dataset and arrive at predictions.

# %%
trainset = data.build_full_trainset()
algo.fit(trainset)

# %% [markdown]
# Let us pick user and check the ratings s/he has given.

# %%
algo.predict(258631, 730)
# Out:
# Prediction(uid=258631, iid=730, r_ui=None, est=0.853708086600472, details={'was_impossible': False})

# %% [markdown]
# For game with ID 730, we get an estimated prediction of **0.8**. One startling feature of this recommender system is that it doesn't care what the game is (or what it contains). It works purely on the basis of an assigned game ID and tries to predict ratings based on how the other users have predicted the game.

# %% [markdown]
# ## Hybrid Recommender
#
# ![](https://www.toonpool.com/user/250/files/hybrid_20095.jpg)

# %% [markdown]
# In this section, I will try to build a simple hybrid recommender that brings together techniques we have implemented in the content based and collaborative filter based engines. This is how it will work:
#
# * **Input:** User ID and the Title of a game
# * **Output:** Similar games sorted on the basis of expected ratings by that particular user.

# %%
def hybrid(userid, title):
    games = recommend(title)
    games['est'] = [algo.predict(userid, x).est for x in games.index]
    games = games.sort_values('est', ascending=False)
    return games.head(10)

# %%
hybrid(592440, 'Counter-Strike')
# Out:
#                               name  positive_ratings  negative_ratings
# appid
# 220                    Half-Life 2             67902              2419  \
# 70                       Half-Life             27755              1100
# 400                         Portal             51801              1080
# 620                       Portal 2            138220              1891
# 500                    Left 4 Dead             17951               948
# 550                  Left 4 Dead 2            251789              8418
# 60                        Ricochet              2758               684
# 30                   Day of Defeat              3416               398
# 330830  Tales from the Borderlands             14338               697
# 22380           Fallout: New Vegas             66756              3149
#
#           owners   reviews release_date               developer
# appid
# 220     20000000  0.965601   2004-11-16                   Valve  \
# 70      10000000  0.961878   1998-11-08                   Valve
# 400     20000000  0.979577   2007-10-10                   Valve
# 620     20000000  0.986504   2011-04-18                   Valve
# 500     10000000  0.949839   2008-11-17                   Valve
# 550     20000000  0.967649   2009-11-19                   Valve
# 60      10000000  0.801278   2000-11-01                   Valve
# 30      10000000  0.895648   2003-05-01                   Valve
# 330830   2000000  0.953642   2014-11-25          Telltale Games
# 22380    5000000  0.954953   2010-10-21  Obsidian Entertainment
#
#                                steamspy_tags
# appid
# 220                    [FPS, Action, Sci-fi]  \
# 70                    [FPS, Classic, Action]
# 400     [Puzzle, First-Person, Singleplayer]
# 620            [Puzzle, Co-op, First-Person]
# 500                    [Zombies, Co-op, FPS]
# 550                    [Zombies, Co-op, FPS]
# 60                [Action, FPS, Multiplayer]
# 30          [FPS, World War II, Multiplayer]
# 330830       [Comedy, Adventure, Story Rich]
# 22380    [Open World, RPG, Post-apocalyptic]
#
#                                            about_the_game
# appid
# 220     1998. HALF-LIFE sends a shock through the game...  \
# 70      Named Game of the Year by over 50 publications...
# 400     <p>Portal&trade; is a new single player game f...
# 620     Portal 2 draws from the award-winning formula ...
# 500     From Valve (the creators of Counter-Strike, Ha...
# 550     Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 60      A futuristic action game that challenges your ...
# 30      Enlist in an intense brand of Axis vs. Allied ...
# 330830  Tales from the Borderlands is a five part epis...
# 22380   Welcome to Vegas. New Vegas.<br>\t\t\t\t\tIt’s...
#
#                                         short_description
# appid
# 220     1998. HALF-LIFE sends a shock through the game...  \
# 70      Named Game of the Year by over 50 publications...
# 400     Portal&trade; is a new single player game from...
# 620     The &quot;Perpetual Testing Initiative&quot; h...
# 500     From Valve (the creators of Counter-Strike, Ha...
# 550     Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 60      A futuristic action game that challenges your ...
# 30      Enlist in an intense brand of Axis vs. Allied ...
# 330830  Tales from the Borderlands is a five part epis...
# 22380       Welcome to Vegas. New Vegas. Enjoy your stay!
#
#                                              header_image
# appid
# 220     https://steamcdn-a.akamaihd.net/steam/apps/220...  \
# 70      https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 400     https://steamcdn-a.akamaihd.net/steam/apps/400...
# 620     https://steamcdn-a.akamaihd.net/steam/apps/620...
# 500     https://steamcdn-a.akamaihd.net/steam/apps/500...
# 550     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 60      https://steamcdn-a.akamaihd.net/steam/apps/60/...
# 30      https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 330830  https://steamcdn-a.akamaihd.net/steam/apps/330...
# 22380   https://steamcdn-a.akamaihd.net/steam/apps/223...
#
#                                                background
# appid
# 220     https://steamcdn-a.akamaihd.net/steam/apps/220...  \
# 70      https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 400     https://steamcdn-a.akamaihd.net/steam/apps/400...
# 620     https://steamcdn-a.akamaihd.net/steam/apps/620...
# 500     https://steamcdn-a.akamaihd.net/steam/apps/500...
# 550     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 60      https://steamcdn-a.akamaihd.net/steam/apps/60/...
# 30      https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 330830  https://steamcdn-a.akamaihd.net/steam/apps/330...
# 22380   https://steamcdn-a.akamaihd.net/steam/apps/223...
#
#                                                   website           publisher
# appid
# 220                             http://www.half-life2.com               Valve  \
# 70                              http://www.half-life.com/               Valve
# 400                    http://www.whatistheorangebox.com/               Valve
# 620                      http://www.thinkwithportals.com/               Valve
# 500                                   http://www.l4d.com/               Valve
# 550                                    http://www.l4d.com               Valve
# 60                                                    NaN               Valve
# 30                            http://www.dayofdefeat.com/               Valve
# 330830  http://www.telltalegames.com/talesfromtheborde...      Telltale Games
# 22380                         http://fallout.bethsoft.com  Bethesda Softworks
#
#              est
# appid
# 220     1.000000
# 70      1.000000
# 400     1.000000
# 620     1.000000
# 500     1.000000
# 550     1.000000
# 60      0.982556
# 30      0.975696
# 330830  0.951527
# 22380   0.951527

# %%
hybrid(3327805, 'Counter-Strike')
# Out:
#                         name  positive_ratings  negative_ratings    owners
# appid
# 400                   Portal             51801              1080  20000000  \
# 220              Half-Life 2             67902              2419  20000000
# 620                 Portal 2            138220              1891  20000000
# 500              Left 4 Dead             17951               948  10000000
# 70                 Half-Life             27755              1100  10000000
# 550            Left 4 Dead 2            251789              8418  20000000
# 604450     Another Adventure              3835               362    100000
# 364360  Total War: WARHAMMER             29826              9878   2000000
# 241240     Contraption Maker               959                92    500000
# 623940       HIVESWAP: Act 1              2909               171    500000
#
#          reviews release_date
# appid
# 400     0.979577   2007-10-10  \
# 220     0.965601   2004-11-16
# 620     0.986504   2011-04-18
# 500     0.949839   2008-11-17
# 70      0.961878   1998-11-08
# 550     0.967649   2009-11-19
# 604450  0.913748   2017-03-10
# 364360  0.751209   2016-05-24
# 241240  0.912464   2014-07-07
# 623940  0.944481   2017-09-14
#
#                                                 developer
# appid
# 400                                                 Valve  \
# 220                                                 Valve
# 620                                                 Valve
# 500                                                 Valve
# 70                                                  Valve
# 550                                                 Valve
# 604450                                 ThankCreate Studio
# 364360  CREATIVE ASSEMBLY;Feral Interactive (Linux);Fe...
# 241240                                    Game Dev Castle
# 623940                           What Pumpkin Games, Inc.
#
#                                        steamspy_tags
# appid
# 400             [Puzzle, First-Person, Singleplayer]  \
# 220                            [FPS, Action, Sci-fi]
# 620                    [Puzzle, Co-op, First-Person]
# 500                            [Zombies, Co-op, FPS]
# 70                            [FPS, Classic, Action]
# 550                            [Zombies, Co-op, FPS]
# 604450                     [Indie, Adventure, Drama]
# 364360                      [Strategy, Fantasy, War]
# 241240                      [Puzzle, Physics, Indie]
# 623940  [Adventure, Point & Click, Great Soundtrack]
#
#                                            about_the_game
# appid
# 400     <p>Portal&trade; is a new single player game f...  \
# 220     1998. HALF-LIFE sends a shock through the game...
# 620     Portal 2 draws from the award-winning formula ...
# 500     From Valve (the creators of Counter-Strike, Ha...
# 70      Named Game of the Year by over 50 publications...
# 550     Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 604450  Another Adventure is a narrative video game.<b...
# 364360  <img src="https://steamcdn-a.akamaihd.net/stea...
# 241240  <strong>** Contraption Maker is a 2-pack. Buy ...
# 623940  Monsters in the yard. Monsters in the house. M...
#
#                                         short_description
# appid
# 400     Portal&trade; is a new single player game from...  \
# 220     1998. HALF-LIFE sends a shock through the game...
# 620     The &quot;Perpetual Testing Initiative&quot; h...
# 500     From Valve (the creators of Counter-Strike, Ha...
# 70      Named Game of the Year by over 50 publications...
# 550     Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 604450                 Just another stupid adventure game
# 364360  Addictive turn-based empire-building with colo...
# 241240  The team that created the original Incredible ...
# 623940  A hand-drawn tribute to hilarious '90s adventu...
#
#                                              header_image
# appid
# 400     https://steamcdn-a.akamaihd.net/steam/apps/400...  \
# 220     https://steamcdn-a.akamaihd.net/steam/apps/220...
# 620     https://steamcdn-a.akamaihd.net/steam/apps/620...
# 500     https://steamcdn-a.akamaihd.net/steam/apps/500...
# 70      https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 550     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 604450  https://steamcdn-a.akamaihd.net/steam/apps/604...
# 364360  https://steamcdn-a.akamaihd.net/steam/apps/364...
# 241240  https://steamcdn-a.akamaihd.net/steam/apps/241...
# 623940  https://steamcdn-a.akamaihd.net/steam/apps/623...
#
#                                                background
# appid
# 400     https://steamcdn-a.akamaihd.net/steam/apps/400...  \
# 220     https://steamcdn-a.akamaihd.net/steam/apps/220...
# 620     https://steamcdn-a.akamaihd.net/steam/apps/620...
# 500     https://steamcdn-a.akamaihd.net/steam/apps/500...
# 70      https://steamcdn-a.akamaihd.net/steam/apps/70/...
# 550     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 604450  https://steamcdn-a.akamaihd.net/steam/apps/604...
# 364360  https://steamcdn-a.akamaihd.net/steam/apps/364...
# 241240  https://steamcdn-a.akamaihd.net/steam/apps/241...
# 623940  https://steamcdn-a.akamaihd.net/steam/apps/623...
#
#                                    website                 publisher       est
# appid
# 400     http://www.whatistheorangebox.com/                     Valve  1.000000
# 220              http://www.half-life2.com                     Valve  1.000000
# 620       http://www.thinkwithportals.com/                     Valve  1.000000
# 500                    http://www.l4d.com/                     Valve  1.000000
# 70               http://www.half-life.com/                     Valve  1.000000
# 550                     http://www.l4d.com                     Valve  1.000000
# 604450      http://another.thankcreate.com        ThankCreate Studio  0.950526
# 364360                                 NaN                      SEGA  0.950526
# 241240         http://contraptionmaker.com                Top Meadow  0.950526
# 623940             http://www.hiveswap.com  What Pumpkin Games, Inc.  0.950526

# %% [markdown]
# We see that for our hybrid recommender, we get different recommendations for different users although the game is the same. Hence, our recommendations are more personalized and tailored towards particular users.

# %% [markdown]
# ## Conclusion
#
# In this notebook, I have built 4 different recommendation engines based on different ideas and algorithms. They are as follows:
#
# 1. **Simple Recommender:** This system used overall Vote Count and Vote Averages to build Top games Charts, in general and for a specific genre. The IMDB Weighted Rating System was used to calculate ratings on which the sorting was finally performed.
# 2. **Content Based Recommender:** We built two content based engines; one that took game overview and taglines as input and the other which took metadata to come up with predictions. We also created a simple filter to give greater preference to games with more votes and higher ratings.
# 3. **Collaborative Filtering:** We used the powerful Surprise Library to build a collaborative filter based on single value decomposition. The RMSE obtained was less than 1 and the engine gave estimated ratings for a given user and game.
# 4. **Hybrid Engine:** We brought together ideas from content and collaborative filterting to build an engine that gave game suggestions to a particular user based on the estimated ratings that it had internally calculated for that user.
